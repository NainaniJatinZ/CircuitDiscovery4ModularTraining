# %%
model_38 = {0: [{2: [2, 6, 7, 0, 9, 5, 4, 1, 3, 8],
   1: [74, 66, 6, 35, 67, 26, 27, 69, 96, 2, 45, 56, 86, 75, 71],
   0: [55, 36, 84, 56, 46, 65, 34, 24, 7, 73, 33, 51, 47, 67, 66]},
  1.4969066868600958,
  194.43528819084167],
 1: [{2: [2, 7, 5, 9, 1, 4, 0, 6, 3, 8],
   1: [57, 42, 63, 33, 78, 8, 90, 7, 91, 97, 61, 14, 92, 22, 1],
   0: [28, 49, 57, 53, 84, 64, 34, 87, 3, 24, 77, 42, 21, 6, 65]},
  0.8908581920280108,
  204.98967289924622],
 2: [{2: [7, 2, 5, 9, 0, 6, 4, 1, 3, 8],
   1: [4, 35, 91, 98, 10, 21, 49, 26, 93, 33, 31, 1, 85, 62, 28],
   0: [91, 36, 66, 94, 11, 69, 41, 60, 13, 72, 25, 40, 51, 29, 43]},
  0.9109174188202904,
  213.7158830165863],
 3: [{2: [3, 2, 4, 0, 7, 1, 5, 9, 6, 8],
   1: [75, 26, 46, 51, 61, 0, 22, 11, 1, 83, 55, 68, 28, 31, 12],
   0: [78, 15, 74, 33, 64, 25, 22, 85, 14, 65, 62, 63, 83, 13, 58]},
  0.9910287504735268,
  223.46996784210205],
 4: [{2: [7, 2, 9, 1, 5, 4, 6, 0, 3, 8],
   1: [46, 56, 68, 45, 80, 85, 0, 43, 24, 92, 28, 62, 73, 13, 8],
   0: [78, 71, 48, 22, 2, 3, 67, 24, 90, 98, 63, 57, 94, 88, 37]},
  5.034395531983767,
  235.01014590263367]}

model_56 = {0: [{2: [7, 0, 8, 5, 6, 2, 3, 9, 4, 1],
   1: [63, 66, 40, 23, 37, 61, 1, 65, 32, 69, 68, 58, 18, 35, 62],
   0: [55, 54, 67, 66, 46, 23, 51, 44, 73, 71, 48, 5, 89, 50, 49]},
  0.9723076512344735,
  223.0387668609619],
 1: [{2: [9, 3, 0, 2, 8, 1, 4, 7, 5, 6],
   1: [35, 57, 24, 33, 25, 42, 55, 90, 1, 7, 51, 63, 14, 84, 50],
   0: [47, 49, 28, 80, 12, 38, 64, 53, 84, 3, 18, 14, 46, 42, 24]},
  1.1244407398545462,
  232.1004250049591],
 2: [{2: [3, 9, 8, 0, 4, 7, 2, 1, 5, 6],
   1: [54, 32, 35, 75, 60, 74, 81, 91, 98, 89, 93, 28, 38, 26, 37],
   0: [91, 36, 41, 29, 72, 76, 43, 13, 83, 10, 64, 37, 60, 78, 7]},
  0.9640563154513052,
  240.2496349811554],
 3: [{2: [4, 3, 5, 8, 0, 7, 1, 2, 9, 6],
   1: [63, 22, 99, 51, 94, 61, 72, 1, 67, 55, 86, 70, 28, 83, 11],
   0: [78, 74, 15, 25, 55, 33, 63, 41, 22, 85, 52, 64, 90, 23, 62]},
  1.319244285710424,
  248.98452615737915],
 4: [{2: [3, 9, 8, 2, 0, 7, 1, 4, 5, 6],
   1: [8, 48, 31, 46, 90, 20, 85, 30, 24, 13, 11, 0, 80, 43, 34],
   0: [78, 48, 16, 90, 24, 57, 63, 22, 95, 49, 13, 18, 30, 66, 37]},
  6.675144498934497,
  258.0258560180664]}

model_comb = {0: [{2: [7, 3, 6, 2, 0, 9, 5, 1, 4, 8],
   1: [63,
    25,
    66,
    36,
    23,
    75,
    39,
    47,
    93,
    31,
    18,
    98,
    71,
    35,
    30,
    37,
    9,
    58,
    32,
    29,
    96,
    90,
    7,
    91,
    0],
   0: [55,
    44,
    54,
    42,
    66,
    67,
    46,
    51,
    73,
    23,
    84,
    11,
    50,
    71,
    48,
    68,
    58,
    13,
    9,
    89,
    1,
    59,
    19,
    92,
    90]},
  1.1036710809517025,
  562.970832824707],
 1: [{2: [5, 3, 2, 9, 7, 4, 1, 0, 8, 6],
   1: [49,
    37,
    57,
    8,
    29,
    42,
    84,
    7,
    25,
    61,
    1,
    92,
    91,
    89,
    90,
    33,
    52,
    38,
    97,
    21,
    19,
    75,
    68,
    14,
    53],
   0: [28,
    45,
    49,
    80,
    53,
    64,
    84,
    57,
    3,
    12,
    24,
    21,
    6,
    42,
    43,
    0,
    4,
    97,
    76,
    44,
    32,
    35,
    78,
    52,
    69]},
  2.397877947860275,
  602.9912509918213],
 2: [{2: [3, 5, 7, 2, 9, 0, 1, 4, 8, 6],
   1: [29,
    42,
    4,
    35,
    23,
    49,
    21,
    85,
    91,
    32,
    89,
    87,
    60,
    31,
    88,
    36,
    15,
    28,
    48,
    3,
    93,
    1,
    27,
    24,
    41],
   0: [91,
    64,
    36,
    4,
    43,
    72,
    10,
    76,
    41,
    68,
    11,
    25,
    60,
    29,
    37,
    94,
    78,
    51,
    40,
    9,
    6,
    92,
    7,
    57,
    33]},
  1.2855709542495888,
  635.9674837589264],
 3: [{2: [3, 4, 0, 2, 5, 7, 1, 9, 6, 8],
   1: [53,
    75,
    46,
    94,
    83,
    81,
    51,
    61,
    55,
    18,
    99,
    1,
    57,
    85,
    13,
    41,
    52,
    28,
    0,
    11,
    68,
    72,
    93,
    65,
    12],
   0: [78,
    74,
    62,
    15,
    14,
    22,
    63,
    25,
    64,
    13,
    85,
    32,
    33,
    86,
    71,
    40,
    26,
    6,
    83,
    90,
    28,
    70,
    80,
    58,
    31]},
  1.6702500199006753,
  669.565886259079],
 4: [{2: [3, 5, 8, 2, 9, 7, 1, 0, 4, 6],
   1: [92,
    87,
    8,
    47,
    43,
    46,
    73,
    80,
    32,
    62,
    49,
    48,
    20,
    45,
    85,
    31,
    68,
    41,
    13,
    30,
    71,
    97,
    28,
    90,
    25],
   0: [48,78,16,7,38,22,24,58,57,67,37,88,63,90,3,2,13,56,30,26,35,53,17, 68, 98]},
  14.15476209648625,
  707.4816381931305]}

# %%
models = ["BIMT", "L1+Local", "L1 Only", "L1 + Swap", "Fully Dense"]
runs = [model_38, model_56, model_comb]
run_length = [5851, 5421, 11272]

# %%
for ind, val in enumerate(models):
    avg_score = 0
    avg_time = 0
    for i, run in enumerate(runs):
        avg_score += run[ind][1]
        avg_time += run[ind][2]/run_length[i]
    print(f"Average Logit Score over 3 runs for {val}: ", avg_score/3)
    print(f"Average Time of Circuit Discovery over 3 runs for {val}: ", avg_time/3)
# Out:
# Average Logit Score over 3 runs for BIMT:  1.1909618063487573
# Average Time of Circuit Discovery over 3 runs for BIMT:  0.041439592332743996
# Average Logit Score over 3 runs for L1+Local:  1.4710589599142772
# Average Time of Circuit Discovery over 3 runs for L1+Local:  0.04378154955135618
# Average Logit Score over 3 runs for L1 Only:  1.0535148961737282
# Average Time of Circuit Discovery over 3 runs for L1 Only:  0.045754940065299864
# Average Logit Score over 3 runs for L1 + Swap:  1.3268410186948756
# Average Time of Circuit Discovery over 3 runs for L1 + Swap:  0.04784130071734136
# Average Logit Score over 3 runs for Fully Dense:  8.621434042468172
# Average Time of Circuit Discovery over 3 runs for Fully Dense:  0.05017593015625247

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Data preparation


models = ["BIMT", "L1+Local", "L1_Only", "L1+Swap", "Fully_Dense"]
logit_score = [1.1909618063487573, 1.4710589599142772, 1.0535148961737282, 1.3268410186948756, 8.621434042468172]
circuit_disc_time = [41.439592332743995, 43.78154955135618, 45.75494006529986, 47.84130071734137, 50.175930156252475]
circuit_sparsity = [0.9908721088435374, 0.9815545918367347, 0.9714345238095238, 0.9753044217687075, 0.9099195578231294]
model_sparsity = [0.920823299319728, 0.9157727891156463, 0.8697651360544217, 0.8711826530612244, 0.008590816326530613]
training_time = [2594.401018857956, 210.89408087730408, 207.30986166000366, 2544.0706374645233, 206.68030834197998] 
inference_time = [6.648291079519148e-05, 6.525390870694661e-05, 6.464214676910465e-05, 6.51559142714447e-05, 6.384146052780856e-05]
memory_allocation_during_training = [1417, 881, 881, 1417, 881]

# Convert data to DataFrame for easier plotting
df = pd.DataFrame({
    'Model': models,
    'Training Time (s)': training_time,
    'Inference Time (us)': [time * 1e6 for time in inference_time],  # Convert to microseconds for better scale
    'Memory Allocation (MB)': memory_allocation_during_training,
    'Model Sparsity': model_sparsity,
    'Circuit Sparsity': circuit_sparsity,
    'Circuit Discovery Time (ms/data)': circuit_disc_time,
    'Logit Score': logit_score
})
df.head()
# Out:
#          Model  Training Time (s)  Inference Time (us)  \
# 0         BIMT        2594.401019            66.482911
# 1     L1+Local         210.894081            65.253909
# 2      L1_Only         207.309862            64.642147
# 3      L1+Swap        2544.070637            65.155914
# 4  Fully_Dense         206.680308            63.841461
#
#    Memory Allocation (MB)  Model Sparsity  Circuit Sparsity  \
# 0                    1417        0.920823          0.990872
# 1                     881        0.915773          0.981555
# 2                     881        0.869765          0.971435
# 3                    1417        0.871183          0.975304
# 4                     881        0.008591          0.909920
#
#    Circuit Discovery Time (ms/data)  Logit Score
# 0                         41.439592     1.190962
# 1                         43.781550     1.471059
# 2                         45.754940     1.053515
# 3                         47.841301     1.326841
# ...

# %%
df.iloc[1], df.iloc[3] =  df.iloc[3].copy(), df.iloc[1].copy()
df.head()
# Out:
#          Model  Training Time (s)  Inference Time (us)  \
# 0         BIMT        2594.401019            66.482911
# 1      L1+Swap        2544.070637            65.155914
# 2      L1_Only         207.309862            64.642147
# 3     L1+Local         210.894081            65.253909
# 4  Fully_Dense         206.680308            63.841461
#
#    Memory Allocation (MB)  Model Sparsity  Circuit Sparsity  \
# 0                    1417        0.920823          0.990872
# 1                    1417        0.871183          0.975304
# 2                     881        0.869765          0.971435
# 3                     881        0.915773          0.981555
# 4                     881        0.008591          0.909920
#
#    Circuit Discovery Time (ms/data)  Logit Score
# 0                         41.439592     1.190962
# 1                         47.841301     1.326841
# 2                         45.754940     1.053515
# 3                         43.781550     1.471059
# ...

# %%
df.iloc[2], df.iloc[3] =  df.iloc[3].copy(), df.iloc[2].copy()
df.head()
# Out:
#          Model  Training Time (s)  Inference Time (us)  \
# 0         BIMT        2594.401019            66.482911
# 1      L1+Swap        2544.070637            65.155914
# 2     L1+Local         210.894081            65.253909
# 3      L1_Only         207.309862            64.642147
# 4  Fully_Dense         206.680308            63.841461
#
#    Memory Allocation (MB)  Model Sparsity  Circuit Sparsity  \
# 0                    1417        0.920823          0.990872
# 1                    1417        0.871183          0.975304
# 2                     881        0.915773          0.981555
# 3                     881        0.869765          0.971435
# 4                     881        0.008591          0.909920
#
#    Circuit Discovery Time (ms/data)  Logit Score
# 0                         41.439592     1.190962
# 1                         47.841301     1.326841
# 2                         43.781550     1.471059
# 3                         45.754940     1.053515
# ...

# %%
df['Model']
# Out:
# 0           BIMT
# 1        L1+Swap
# 2       L1+Local
# 3        L1_Only
# 4    Fully_Dense
# Name: Model, dtype: object

# %%
import pandas as pd
import seaborn as sns

# Start plotting
sns.set_theme(style="whitegrid")

# Create a barplot
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x="Model", y="Training Time (s)", data=df, palette="Blues_d")

# Annotate each bar with the numerical value
for p in barplot.patches:
    barplot.annotate(format(int(p.get_height())), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', 
                     size=10,
                     xytext = (0, 9), 
                     textcoords = 'offset points')

# Make the first label of x axis bold
for label in barplot.get_xticklabels():  # Get x labels
    if label.get_text() == df["Model"][0]:  # If it's the first label
        label.set_weight('bold')
        break  # No need to check other labels

# Final touches
plt.title('Training Time for Different Models')
plt.xlabel('Model Name')
plt.ylabel('Training Time (seconds)')
# plt.xticks(rotation=45)
plt.tight_layout()  # Fit plot within the figure nicely

plt.show()
# Out:
# /var/folders/th/y7ztqcmn4zb5smzvyg91mt380000gn/T/ipykernel_6972/1564447245.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x="Model", y="Training Time (s)", data=df, palette="Blues_d")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame containing the data

# Start plotting
sns.set_theme(style="whitegrid")

# Create custom color palette
# First two bars in red to signify the massive training time
# Rest of the bars in blue
# colors = ['#e57373', '#e57373'] + ['#64b5f6'] * (len(df) - 2)

import matplotlib.colors as mcolors

# Normalize the training time data to a range between 0 and 1
norm = plt.Normalize(df['Training Time (s)'].min(), df['Training Time (s)'].max())

# Create a color map that scales with the training time values
colors = plt.cm.ScalarMappable(norm=norm, cmap=mcolors.LinearSegmentedColormap.from_list("", ["#64b5f6", "#e57373"])).to_rgba(df['Training Time (s)'])


# Create a barplot
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x="Model", y="Training Time (s)", data=df, palette=colors)

# Annotate each bar with the numerical value
for p in barplot.patches:
    barplot.annotate(format(int(p.get_height())),
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center',
                     size=11,
                     xytext=(0, 9),
                     textcoords='offset points')

# Make the first label of x axis bold
for label in barplot.get_xticklabels():  # Get x labels
    if label.get_text() == df["Model"][0]:  # If it's the first label
        label.set_weight('bold')
        break  # No need to check other labels

# Final touches
plt.title('Training Time for Different Models')
plt.xlabel('Model')
plt.ylabel('Training Time (seconds)')
plt.tight_layout()  # Fit plot within the figure nicely

plt.show()
# Out:
# /var/folders/th/y7ztqcmn4zb5smzvyg91mt380000gn/T/ipykernel_6972/4286722413.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x="Model", y="Training Time (s)", data=df, palette=colors)
# /var/folders/th/y7ztqcmn4zb5smzvyg91mt380000gn/T/ipykernel_6972/4286722413.py:26: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   barplot = sns.barplot(x="Model", y="Training Time (s)", data=df, palette=colors)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame containing the data

# Start plotting
sns.set_theme(style="whitegrid")

# # Memory Allocation Graph
# plt.bar(df['Model'], df["Memory Allocation (MB)"], color='green')
# plt.xlabel('Model')
# plt.ylabel('Memory Allocation (MB)')
# plt.title('Memory Allocation During Training for Each Model')
# # plt.grid()
# plt.show()

# Create custom color palette
# First two bars in red to signify the massive training time
# Rest of the bars in blue
# colors = ['#e57373', '#e57373'] + ['#64b5f6'] * (len(df) - 2)

import matplotlib.colors as mcolors

# Normalize the training time data to a range between 0 and 1
norm = plt.Normalize(df["Memory Allocation (MB)"].min(), df["Memory Allocation (MB)"].max())

# Create a color map that scales with the training time values
colors = plt.cm.ScalarMappable(norm=norm, cmap=mcolors.LinearSegmentedColormap.from_list("", ["#64b5f6", "#e57373"])).to_rgba(df["Memory Allocation (MB)"])


# Create a barplot
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x="Model", y="Memory Allocation (MB)", data=df, palette=colors)

# Annotate each bar with the numerical value
for p in barplot.patches:
    barplot.annotate(format(int(p.get_height())),
                     (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center',
                     size=11,
                     xytext=(0, 9),
                     textcoords='offset points')

# Make the first label of x axis bold
for label in barplot.get_xticklabels():  # Get x labels
    if label.get_text() == df["Model"][0]:  # If it's the first label
        label.set_weight('bold')
        break  # No need to check other labels

# Final touches
plt.title('Memory Allocation for Different Models')
plt.xlabel('Model')
plt.ylabel("Memory Allocation (MB)")
plt.tight_layout()  # Fit plot within the figure nicely

plt.show()
# Out:
# /var/folders/th/y7ztqcmn4zb5smzvyg91mt380000gn/T/ipykernel_6972/1427611966.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x="Model", y="Memory Allocation (MB)", data=df, palette=colors)
# /var/folders/th/y7ztqcmn4zb5smzvyg91mt380000gn/T/ipykernel_6972/1427611966.py:34: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   barplot = sns.barplot(x="Model", y="Memory Allocation (MB)", data=df, palette=colors)

# %%
# Training and Inference Time Graph
fig, ax1 = plt.subplots()
ax1.plot(df['Model'], df['Training Time (s)'], color='b', label='Training Time', marker='o')
ax2 = ax1.twinx()
ax2.plot(df['Model'], df['Inference Time (us)'], color='r', label='Inference Time', marker='x')
ax1.set_xlabel('Model')
ax1.set_ylabel('Training Time (s)', color='b')
ax2.set_ylabel('Inference Time (us)', color='r')
plt.title('Training and Inference Time for Each Model')
plt.grid()
plt.show()

# Memory Allocation Graph
plt.bar(df['Model'], df["Memory Allocation (MB)"], color='green')
plt.xlabel('Model')
plt.ylabel('Memory Allocation (MB)')
plt.title('Memory Allocation During Training for Each Model')
# plt.grid()
plt.show()

# Network and Circuit Sparsity Comparison
plt.plot(df['Model'], df["Model Sparsity"], label='Network Sparsity', marker='o')
plt.plot(df['Model'], df["Circuit Sparsity"], label='Circuit Sparsity', marker='x')
plt.xlabel('Model')
plt.ylabel('Sparsity Level')
plt.title('Comparison of Network and Circuit Sparsity')
plt.legend()
plt.grid()
plt.show()

# Circuit Discovery Metrics Table
df_circuit_metrics = pd.DataFrame({
    'Model': models,
    'Circuit Discovery Time (s)': circuit_disc_time,
    'Circuit Sparsity': circuit_sparsity,
    'Logit Score': logit_score
})
print("\nCircuit Discovery Metrics Table:")
print(df_circuit_metrics)

# Circuit Evaluation Graph
plt.scatter(logit_score, circuit_sparsity)
plt.xlabel('Logit Score')
plt.ylabel('Circuit Sparsity')
plt.title('Circuit Sparsity vs Logit Score')
for i, txt in enumerate(models):
    plt.annotate(txt, (logit_score[i]-0.4, circuit_sparsity[i]))
plt.grid()
plt.show()
# Out:
# Circuit Discovery Metrics Table:
#          Model  Circuit Discovery Time (s)  Circuit Sparsity  Logit Score
# 0         BIMT                   41.439592          0.990872     1.190962
# 1     L1+Local                   43.781550          0.981555     1.471059
# 2      L1 Only                   45.754940          0.971435     1.053515
# 3    L1 + Swap                   47.841301          0.975304     1.326841
# 4  Fully Dense                   50.175930          0.909920     8.621434
